# %%
import os

os.chdir('/Users/paulynnyu/twitter/tweepy-bots')

# %%
#!pip install tweepy
# Out:
# '/Users/paulynnyu/twitter/tweepy-bots'

# %%
import tweepy
import json
from collections import defaultdict
import pandas as pd
import numpy as np
# tweepy-bots/bots/config.py

# %%
auth = tweepy.OAuthHandler("5SDCerBHlWzSBAzvBXonhZ6Xe", "8zeJxu7srcQN6uhQAvcsWXHM8q8pVdzys6g6kfyeQhyVLcdcIR")
auth.set_access_token("2263992234-pp4lcAeHd7sYOOrlbjKfCPea7BC4vBr1xZoifce",
    "RRcgaj400e2ubOFuiy8YwrvTBsjxs19YVhQB1tFYcN5lA")

api = tweepy.API(auth)

# %%
# try:
#     api.verify_credentials()
#     print("Authentication OK")
# except:
#     print("Error during authentication")
# Out:
# Authentication OK

# %%
# Returns an array containing the IDs of users following the specified user.
user_ids = api.followers_ids(screen_name='OddStats')

# %%
len(user_ids['ids'])
# Out:
# 5000

# %%
user_id2 = api.followers_ids(screen_name='OddStats',cursor=-2)

# %%
len(user_id2[0]['ids'])
# Out:
# 5000

# %%
user_id2[:5]
# Out:
# ({'ids': [776608042485854209,
#    776950550562832386,
#    3351411167,
#    260089175,
#    18776045,
#    42399292,
#    874023087775162368,
#    791789718572634112,
#    501564954,
#    86507629,
#    149085721,
#    2957349219,
#    722947870966591488,
#    800169250933469184,
#    1544443327,
#    996921126528933888,
#    1156027926,
#    983765957884694529,
#    287783936,
#    287960815,
#    351124316,
#    75951670,
#    80660848,
#    136020757,
#    57436131,
#    764965224667504640,
#    1676916738,
#    262962287,
#    49336461,
#    721241749,
#    993734816,
#    925797944925724672,
#    889196334598807552,
#    801484316,
#    599775698,
#    2363678166,
#    48030192,
#    355102832,
#    437345319,
#    84737832,
#    407534902,
#    30613782,
#    1264940040,
#    708908761448972288,
#    803692100759986176,
#    12624252,
#    369796744,
#    165239869,
#    1005127055086845952,
#    1003904418993979392,
#    1225774069,
#    390670821,
#    577623319,
#    1005102951793340416,
#    838543337858691074,
#    3056474826,
#    237861624,
#    285022658,
#    778239509599223808,
#    370554514,
#    1004971808599273472,
#    2775149427,
#    4429892907,
#    2176420138,
#    40420914,
#    754340642201931776,
#    48472902,
#    333602181,
#    982531822113427456,
#    50383929,
#    360782411,
#    1004743462468575232,
#    1004759730504523776,
#    1004681303009079296,
#    2325360643,
#    1004744105711161345,
#    1434457861,
#    37436862,
#    879424621606572032,
#    854029895327809536,
#    4504207401,
#    2188045354,
#    16173516,
#    24443284,
#    2438358464,
#    970200970176159744,
#    370774463,
#    853986664645095425,
#    2497053697,
#    288980311,
#    29103529,
#    48845306,
#    2512812821,
#    1001446359529029632,
#    947145763,
#    190283221,
#    14772022,
#    2464000518,
#    140148161,
#    128369982,
#    891413880055975941,
#    955707551030677504,
#    176839085,
#    20501514,
#    67244816,
#    937369940222513152,
#    3366223905,
#    3245043472,
#    1834249489,
#    109608118,
#    291899184,
#    2273211236,
#    987804587238150144,
#    788844558616375297,
#    96475775,
#    2817846992,
#    4197095417,
#    16105217,
#    211937933,
#    997509902,
#    182272044,
#    1339862269,
#    282803003,
#    384907010,
#    4789508894,
#    4505169808,
#    2897827275,
#    21917683,
#    407382454,
#    77132690,
#    315417743,
#    55354528,
#    3000696865,
#    2388202753,
#    1421274542,
#    305108599,
#    913379071,
#    550006554,
#    364869465,
#    282283356,
#    2636154388,
#    39896478,
#    396923237,
#    4018731209,
#    940772438245347328,
#    765177974819852288,
#    87522527,
#    4549072574,
#    1317361410,
#    4861470728,
#    834164407,
#    956595854,
#    3895853063,
#    16433168,
#    246723672,
#    1673865013,
#    467497807,
#    996592397885853697,
#    329381484,
#    993501715914780677,
#    44973794,
#    53308845,
#    997710367290605569,
#    22836487,
#    904198365734424576,
#    26380590,
#    908927915081027584,
#    286901888,
#    627838164,
#    2409299750,
#    52152856,
#    816291533368348674,
#    195208940,
#    913492040712941568,
#    2300652684,
#    740687155,
#    17995154,
#    253380111,
#    3005127850,
#    124634876,
#    27980718,
#    985745482726031361,
#    369715982,
#    2873691249,
#    4005876677,
#    3064520638,
#    150688218,
#    371035961,
#    103320288,
#    617529633,
#    322617264,
#    43349506,
#    266200540,
#    985791670737424384,
#    2992564948,
#    997061292635643904,
#    64046698,
#    868162232969986049,
#    979646064,
#    748304552026218496,
#    731680736437100547,
#    858782513317249025,
#    329403962,
#    318146252,
#    890402135749181440,
#    2723816598,
#    997120574127329281,
#    271314265,
#    2831713653,
#    3004432225,
#    902512592,
#    2564397163,
#    736699556,
#    3094250805,
#    160930977,
#    743461134640906241,
#    4801184916,
#    1220046626,
#    380991440,
#    145325285,
#    26123606,
#    69408259,
#    988300472770486272,
#    997087112984973312,
#    59247428,
#    130602700,
#    1666461426,
#    269948307,
#    947391819356151808,
#    3234812708,
#    30743823,
#    997066687575920640,
#    4597200012,
#    2956705124,
#    1401712627,
#    121008418,
#    1581464005,
#    256836369,
#    15410025,
#    780533844,
#    580705801,
#    936234957944393729,
#    1075653242,
#    2208977984,
#    2717784160,
#    933557288794648576,
#    890164168158064640,
#    ...],
#   'next_cursor': 1581165063722594763,
#   'next_cursor_str': '1581165063722594763',
#   'previous_cursor': -1602793312648715547,
#   'previous_cursor_str': '-1602793312648715547',
#   'total_count': None},
#  (-1602793312648715547, 1581165063722594763))

# %%
# get the api wait limit
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True, parser=tweepy.parsers.JSONParser())

# %%
user_list = user_id2[0]['ids']

# %%
def get_details(my_list):
    # list of user attributes and post attributes we want to collect
    attributes = ['name', 'screen_name', 'location', 'description', 'url', 'protected', 'followers_count', 
                 'following', 'friends_count', 'listed_count', 'geo_enabled', 'created_at', 'favourites_count',
                 'statuses_count', 'contributors_enabled', 'is_translation_enabled', 'has_extended_profile',
                 'notifications', 'profile_image_url', 'profile_use_background_image']
    post_attrs = ['created_at', 'text', 'source', 'in_reply_to_screen_name', 'retweet_count', 'favorite_count',
               'favorited', 'retweeted', 'is_quote_status', 'retweeted_status']
    entities_attrs = ['hashtags', 'symbols', 'user_mentions']

    # start looping through our list
    for users in user_list:

        user_dict = defaultdict(list)
        post_dict = defaultdict(list)
        user['user_id'] = users

        try:
            timeline = api.user_timeline(user_id=users, count=200) # call api

            user_info = timeline[0]['user'] # creating a user_info and post dicts

            # looping through each user attribute
            for attribute in attributes:
                try:
                    user_dict[attribute].append(user_info[attribute])

                except:
                    user_dict[attribute].append(np.nan)

            # looping through each post, and each post attribute 
            for tweets in timeline:
                post['user_id'] = user['user_id']

                # looping through entities attributes
                for attr in entities_attrs:
                    try:
                        post_dict[attr].append(tweets['entities'][attr])
                        attr_name = 'len_' + attr
                        post_dict[attr_name].append(len(tweets['entities'][attr]))
                    except:
                        post_dict[attr].append(np.nan)

                # looping through other post attributes
                for attr in post_attrs:
                    try:
                        post_dict[attr].append(tweets[attr])
                    except:
                        post_dict[attr].append(np.nan)

        except:
            user['not_authorized'].append(1)
        
        
        return pd.DataFrame(user_dict), pd.DataFrame(post_dict)

# %%
pd.DataFrame(post_dict)
# Out:
#     hashtags  len_hashtags                                 symbols  \
# 0         []             0                                      []
# 1         []             0                                      []
# 2         []             0                                      []
# 3         []             0                                      []
# 4         []             0                                      []
# ..       ...           ...                                     ...
# 195       []             0                                      []
# 196       []             0                                      []
# 197       []             0                                      []
# 198       []             0  [{'text': 'NDX', 'indices': [20, 24]}]
# 199       []             0                                      []
#
#      len_symbols                                      user_mentions  \
# 0              0  [{'screen_name': 'FirstSquawk', 'name': 'First...
# 1              0  [{'screen_name': 'Flash430', 'name': 'DB = No ...
# 2              0  [{'screen_name': 'trading_pl', 'name': 'Tomasz...
# 3              0  [{'screen_name': 'zerohedge', 'name': 'zerohed...
# 4              0  [{'screen_name': 'MaciekSankowski', 'name': 'M...
# ..           ...                                                ...
# 195            0  [{'screen_name': 'zerohedge', 'name': 'zerohed...
# 196            0  [{'screen_name': 'NorthmanTrader', 'name': 'Sv...
# 197            0  [{'screen_name': 'NorthmanTrader', 'name': 'Sv...
# 198            1  [{'screen_name': 'NorthmanTrader', 'name': 'Sv...
# 199            0  [{'screen_name': 'zerohedge', 'name': 'zerohed...
#
#      len_user_mentions                      created_at  \
# 0                    1  Wed Oct 16 17:17:41 +0000 2019
# 1                    2  Wed Oct 16 17:15:03 +0000 2019
# 2                    1  Wed Oct 16 08:54:39 +0000 2019
# 3                    1  Tue Oct 15 18:42:44 +0000 2019
# 4                    1  Tue Oct 15 16:05:04 +0000 2019
# ..                 ...                             ...
# 195                  1  Thu Sep 12 15:40:45 +0000 2019
# 196                  1  Thu Sep 12 15:40:19 +0000 2019
# 197                  1  Thu Sep 12 12:33:40 +0000 2019
# 198                  1  Thu Sep 12 12:29:01 +0000 2019
# 199                  1  Thu Sep 12 12:28:36 +0000 2019
#
#                                                   text  \
# 0                 @FirstSquawk https://t.co/z742bWe2Ey
# 1    @Flash430 @zerohedge They gonna need these fig...
# 2    @trading_pl Moja propozycja na rynek USA. Cash...
# 3    RT @zerohedge: It's time to price in last Frid...
# 4                        @MaciekSankowski to jest news
# ..                                                 ...
# 195  RT @zerohedge: TRUMP ADMIN "ABSOLUTELY NOT" CO...
# 196  RT @NorthmanTrader: Trump’s short again https:...
# 197  RT @NorthmanTrader: Since nobody will say it I...
# 198  RT @NorthmanTrader: $NDX weekly chart.\nBest o...
# 199  RT @zerohedge: Trump tweets that Draghi is hir...
#
#                                                 source  \
# 0    <a href="http://twitter.com/download/android" ...
# 1    <a href="http://twitter.com/download/android" ...
# 2    <a href="http://twitter.com/download/android" ...
# 3    <a href="http://twitter.com/download/android" ...
# 4    <a href="https://mobile.twitter.com" rel="nofo...
# ..                                                 ...
# 195  <a href="http://twitter.com/download/android" ...
# 196  <a href="http://twitter.com/download/android" ...
# 197  <a href="http://twitter.com/download/android" ...
# 198  <a href="http://twitter.com/download/android" ...
# 199  <a href="http://twitter.com/download/android" ...
#
#     in_reply_to_screen_name  retweet_count  favorite_count  favorited  \
# 0               FirstSquawk              0               1      False
# 1                  Flash430              0               1      False
# 2                trading_pl              0               1      False
# 3                      None             15               0      False
# 4           MaciekSankowski              0               1      False
# ..                      ...            ...             ...        ...
# 195                    None            241               0      False
# 196                    None             31               0      False
# 197                    None            186               0      False
# 198                    None             16               0      False
# 199                    None            114               0      False
#
#      retweeted  is_quote_status  \
# 0        False            False
# 1        False            False
# 2        False            False
# 3        False             True
# 4        False            False
# ..         ...              ...
# 195      False            False
# 196      False             True
# 197      False            False
# 198      False            False
# 199      False            False
#
#                                       retweeted_status
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    {'created_at': 'Tue Oct 15 18:28:47 +0000 2019...
# 4                                                  NaN
# ..                                                 ...
# 195  {'created_at': 'Thu Sep 12 14:51:18 +0000 2019...
# 196  {'created_at': 'Thu Sep 12 14:51:43 +0000 2019...
# 197  {'created_at': 'Thu Sep 12 12:31:49 +0000 2019...
# 198  {'created_at': 'Thu Sep 12 11:59:29 +0000 2019...
# 199  {'created_at': 'Thu Sep 12 12:04:33 +0000 2019...
#
# [200 rows x 16 columns]

# %%
len(post_dict['user_mentions'][5])
# Out:
# 1

# %%
pd.DataFrame(post_dict).user_mentions
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 195   NaN
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# Name: user_mentions, Length: 200, dtype: float64

# %%
try:
    user['name'].append(timeline[0]['user']['name'])
    user['screen_name'].append(timeline[0]['user']['screen_name'])
    user['location'].append(timeline[0]['user']['location'])
    user['description'].append(timeline[0]['user']['description'])
    user['url'].append(timeline[0]['user']['url'])
    user['protected'].append(timeline[0]['user']['protected'])
    user['followers_cnt'].append(timeline[0]['user']['followers_count'])
    user['following_cnt'].append(timeline[0]['user']['following'])
    user['friends_cnt'].append(timeline[0]['user']['friends_count'])
    user['listed_cnt'].append(timeline[0]['user']['listed_count'])
    user['geo_enabled'].append(timeline[0]['user']['geo_enabled'])
    user['created_at'].append(timeline[0]['user']['created_at'])
    user['favorites_cnt'].append(timeline[0]['user']['favourites_count'])
    user['statuses_cnt'].append(timeline[0]['user']['statuses_count'])
    user['contributors_enabled'].append(timeline[0]['user']['contributors_enabled'])
    user['translation_enabled'].append(timeline[0]['user']['is_translation_enabled'])
    user['extended_profile'].append(timeline[0]['user']['has_extended_profile'])
    user['notifications'].append(timeline[0]['user']['notifications'])
    user['profile_image'].append(timeline[0]['user']['profile_image_url'])
    user['profile_background_YN'].append(timeline[0]['user']['profile_use_background_image'])



    post = defaultdict(list)
    for tweets in timeline:
    # getting first details

    
    
#     print(tweet)
        post['user_id'] = user['user_id']
        post['date'].append(tweets['created_at'])
        post['text'].append(tweets['text'])
        post['hashtags'].append(tweets['entities']['hashtags'])
        post['len_hashtags'].append(len(tweets['entities']['hashtags']))
        post['symbols'].append(tweets['entities']['symbols'])
        post['len_symbols'].append(len(tweets['entities']['symbols']))
        post['len_user_mentions'].append(len(tweets['entities']['user_mentions']))
        post['source'].append(tweets['source'])
        post['reply_to'].append(tweets['in_reply_to_screen_name'])
        post['retweet'].append(tweets['retweet_count'])
        post['favorite_cnt'].append(tweets['favorite_count'])
        post['favorited'].append(tweets['favorited'])
        post['retweeted'].append(tweets['retweeted'])
        post['is_quote_status'].append(tweets['is_quote_status'])
        if tweets.get('retweeted_status'," "):
            post['retweet_status_YN'].append(len(tweets.get('retweeted_status'," ")) >2)
    #         post['len_retweet_content'].append(tweets.get('retweeted_status'," "))

    post = pd.DataFrame(post)
    user = pd.DataFrame(user)

except:
    user['empty'].append(1)


# print(pd.DataFrame(post))

# print(pd.DataFrame(user))

# %%
post.head(4)
# Out:
#               user_id                            date  \
# 0  970200970176159744  Wed Oct 16 17:17:41 +0000 2019
# 1  970200970176159744  Wed Oct 16 17:15:03 +0000 2019
# 2  970200970176159744  Wed Oct 16 08:54:39 +0000 2019
# 3  970200970176159744  Tue Oct 15 18:42:44 +0000 2019
#
#                                                 text hashtags  len_hashtags  \
# 0               @FirstSquawk https://t.co/z742bWe2Ey       []             0
# 1  @Flash430 @zerohedge They gonna need these fig...       []             0
# 2  @trading_pl Moja propozycja na rynek USA. Cash...       []             0
# 3  RT @zerohedge: It's time to price in last Frid...       []             0
#
#   symbols  len_symbols  len_user_mentions  \
# 0      []            0                  1
# 1      []            0                  2
# 2      []            0                  1
# 3      []            0                  1
#
#                                               source     reply_to  retweet  \
# 0  <a href="http://twitter.com/download/android" ...  FirstSquawk        0
# 1  <a href="http://twitter.com/download/android" ...     Flash430        0
# 2  <a href="http://twitter.com/download/android" ...   trading_pl        0
# 3  <a href="http://twitter.com/download/android" ...         None       15
#
#    favorite_cnt  favorited  retweeted  is_quote_status  retweet_status_YN
# 0             1      False      False            False              False
# 1             1      False      False            False              False
# 2             1      False      False            False              False
# 3             0      False      False             True               True

# %%
user
# Out:
# defaultdict(list,
#             {'name': ['Radosław Kułajewicz'],
#              'screen_name': ['Gordi38pl'],
#              'location': [''],
#              'description': ['Financial market speculator.Working class of trading. Bearish'],
#              'url': [None],
#              'protected': [False],
#              'followers_cnt': [192],
#              'following_cnt': [False],
#              'friends_cnt': [531],
#              'listed_cnt': [2],
#              'geo_enabled': [False],
#              'created_at': ['Sun Mar 04 07:35:11 +0000 2018'],
#              'favorites_cnt': [9807],
#              'statuses_cnt': [3036],
#              'contributors_enabled': [False],
#              'translation_enabled': [False],
#              'extended_profile': [True],
#              'notifications': [False],
#              'profile_image': ['http://pbs.twimg.com/profile_images/1024391202664329217/u8DF6OKH_normal.jpg'],
#              'profile_background_YN': [True],
#              'extended_profile_YN': [True],
#              'user_id': [],
#              'empty': [1]})

# %%
import pprint as pp
import json

import tweepy
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
tweets = api.user_timeline(screen_name='ultimetis', count=10)

# %%
for tweet in tweets:
    print(tweet['created_at'])
    break
# Out:
# Wed Oct 16 00:14:49 +0000 2019

# %%
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
tweets = api.user_timeline(screen_name='ultimetis', count=10)

# %%
home = api.home_timeline(screen_name='ultimetis', count=1)
home

# %%
home[0]
# Out:
# {'created_at': 'Wed Oct 16 00:31:27 +0000 2019',
#  'id': 1184265562182029312,
#  'id_str': '1184265562182029312',
#  'text': "RT @GENmag: Hey, this is feminist columnist &amp; author @JessicaValenti - I'll be tweeting about the #DemDebate tonight for GEN! (I guess I'll…",
#  'truncated': False,
#  'entities': {'hashtags': [{'text': 'DemDebate', 'indices': [102, 112]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'GENmag',
#     'name': 'GEN by Medium',
#     'id': 1135617816957247488,
#     'id_str': '1135617816957247488',
#     'indices': [3, 10]},
#    {'screen_name': 'JessicaValenti',
#     'name': 'Jessica Valenti',
#     'id': 4099171,
#     'id_str': '4099171',
#     'indices': [57, 72]}],
#   'urls': []},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 571202103,
#   'id_str': '571202103',
#   'name': 'Medium',
#   'screen_name': 'Medium',
#   'location': 'San Francisco, CA, US',
#   'description': 'Words matter. Learn more at https://t.co/KXvi8xUeaK. For support go to @MediumSupport or https://t.co/A7QR3wf377. To contact us,  email yourfriends@medium.com.',
#   'url': 'https://t.co/JV5396gd2O',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/JV5396gd2O',
#       'expanded_url': 'http://medium.com',
#       'display_url': 'medium.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/KXvi8xUeaK',
#       'expanded_url': 'http://medium.com/about',
#       'display_url': 'medium.com/about',
#       'indices': [28, 51]},
#      {'url': 'https://t.co/A7QR3wf377',
#       'expanded_url': 'http://help.medium.com',
#       'display_url': 'help.medium.com',
#       'indices': [89, 112]}]}},
#   'protected': False,
#   'followers_count': 2298414,
#   'friends_count': 110,
#   'listed_count': 13387,
#   'created_at': 'Fri May 04 20:16:39 +0000 2012',
#   'favourites_count': 6304,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 33673,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/900033008685666305/c6Q38U35_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/900033008685666305/c6Q38U35_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/571202103/1552491973',
#   'profile_link_color': '00AB69',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': True,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Tue Oct 15 23:53:56 +0000 2019',
#   'id': 1184256123806867456,
#   'id_str': '1184256123806867456',
#   'text': "Hey, this is feminist columnist &amp; author @JessicaValenti - I'll be tweeting about the #DemDebate tonight for GEN! (… https://t.co/sm0r67bFxW",
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'DemDebate', 'indices': [90, 100]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'JessicaValenti',
#      'name': 'Jessica Valenti',
#      'id': 4099171,
#      'id_str': '4099171',
#      'indices': [45, 60]}],
#    'urls': [{'url': 'https://t.co/sm0r67bFxW',
#      'expanded_url': 'https://twitter.com/i/web/status/1184256123806867456',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}]},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1135617816957247488,
#    'id_str': '1135617816957247488',
#    'name': 'GEN by Medium',
#    'screen_name': 'GENmag',
#    'location': '',
#    'description': 'A new publication by @Medium about politics, power, and culture.',
#    'url': 'https://t.co/UuONLHVuHK',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UuONLHVuHK',
#        'expanded_url': 'http://gen.medium.com',
#        'display_url': 'gen.medium.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3739,
#    'friends_count': 10,
#    'listed_count': 36,
#    'created_at': 'Mon Jun 03 18:42:41 +0000 2019',
#    'favourites_count': 13,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3205,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1138773832154566659/RslVRqtZ_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1138773832154566659/RslVRqtZ_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1135617816957247488/1560350673',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 9,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 3,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
tweetIDs = ['591495703','1123627938316865536','93700950']
twits = api.statuses_lookup(tweetIDs)

for tweet in twits:
   #tweet obtained
   print(str(tweet['id'])+str(tweet['text']))

# %%
api.user_timeline(id=121191600)[1]
# Out:
# {'created_at': 'Mon Oct 07 22:53:56 +0000 2019',
#  'id': 1181341917885452289,
#  'id_str': '1181341917885452289',
#  'text': "@mrdbourke I'm going to guess, those same folks spend more than $100 a month eating out and consuming adult beverag… https://t.co/74pAO3WrCA",
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'mrdbourke',
#     'name': 'Daniel Bourke',
#     'id': 743086819,
#     'id_str': '743086819',
#     'indices': [0, 10]}],
#   'urls': [{'url': 'https://t.co/74pAO3WrCA',
#     'expanded_url': 'https://twitter.com/i/web/status/1181341917885452289',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': 1181165004382359552,
#  'in_reply_to_status_id_str': '1181165004382359552',
#  'in_reply_to_user_id': 743086819,
#  'in_reply_to_user_id_str': '743086819',
#  'in_reply_to_screen_name': 'mrdbourke',
#  'user': {'id': 121191600,
#   'id_str': '121191600',
#   'name': 'Johann Beukes',
#   'screen_name': 'JohannJBBeukes',
#   'location': 'Tequesta, FL',
#   'description': '#DataScience #MachineLearning #AI #PredictiveAnalytics #PlantBasedDiet #MartialArts #Fitness #Levatas #ReconAI',
#   'url': 'https://t.co/sPZtXeyagS',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/sPZtXeyagS',
#       'expanded_url': 'http://www.JohannBeukes.com',
#       'display_url': 'JohannBeukes.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 2710,
#   'friends_count': 1412,
#   'listed_count': 244,
#   'created_at': 'Mon Mar 08 18:28:58 +0000 2010',
#   'favourites_count': 3249,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 3230,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1078681045833265152/0I9OGbKN_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1078681045833265152/0I9OGbKN_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/121191600/1551369172',
#   'profile_link_color': '067299',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 1,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
#Returns an user’s friends ordered in which they were added 100 at a time. If no user is specified it defaults to the authenticated user.
tweets = api.friends(id=121191600)

for tweet in tweets:
    pp.pprint(tweet)
    break
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-237-103a5ff9f354> in <module>
#       1 #Returns an user’s friends ordered in which they were added 100 at a time. If no user is specified it defaults to the authenticated user.
# ----> 2 tweets = api.friends(id=1184261378334265344)
#       3
#       4 for tweet in tweets:
#       5     pp.pprint(tweet)
#
# //anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# //anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     229
#     230                 if is_rate_limit_error_message(error_msg):
# --> 231                     raise RateLimitError(error_msg, resp)
#     232                 else:
#     233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#
# RateLimitError: [{'message': 'Rate limit exceeded', 'code': 88}]

# %%
# tweets

# %%
members = api.list_members(list_id=1130185227375038465,screen_name='twitterdev')

# %%
members
# Out:
# {'users': [{'id': 2244994945,
#    'id_str': '2244994945',
#    'name': 'Twitter Dev',
#    'screen_name': 'TwitterDev',
#    'location': 'Internet',
#    'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter',
#    'url': 'https://t.co/FGl7VOULyL',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL',
#        'expanded_url': 'https://developer.twitter.com/',
#        'display_url': 'developer.twitter.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1',
#        'expanded_url': 'https://twittercommunity.com/',
#        'display_url': 'twittercommunity.com',
#        'indices': [93, 116]}]}},
#    'protected': False,
#    'followers_count': 504771,
#    'friends_count': 1468,
#    'listed_count': 1571,
#    'created_at': 'Sat Dec 14 04:35:55 +0000 2013',
#    'favourites_count': 2198,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 3437,
#    'lang': None,
#    'status': {'created_at': 'Fri Sep 20 22:11:31 +0000 2019',
#     'id': 1175170649968349184,
#     'id_str': '1175170649968349184',
#     'text': 'Check out this summary of our recent #TapIntoTwitterLA + @NASAJPL MeetUp workshop! 🚀🤖👇https://t.co/457khkpJgF',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'TapIntoTwitterLA',
#        'indices': [37, 54]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'NASAJPL',
#        'name': 'NASA JPL',
#        'id': 19802879,
#        'id_str': '19802879',
#        'indices': [57, 65]}],
#      'urls': [{'url': 'https://t.co/457khkpJgF',
#        'expanded_url': 'https://blog.twitter.com/developer/en_us/topics/community/2019/tapintotwitter-nasa-recap-blog.html',
#        'display_url': 'blog.twitter.com/developer/en_u…',
#        'indices': [86, 109]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 39,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   {'id': 6253282,
#    'id_str': '6253282',
#    'name': 'Twitter API',
#    'screen_name': 'TwitterAPI',
#    'location': 'San Francisco, CA',
#    'description': "The Real Twitter API. Tweets about API changes, service issues and our Developer Platform. Don't get an answer? It's on my website.",
#    'url': 'https://t.co/8IkCzCDr19',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8IkCzCDr19',
#        'expanded_url': 'https://developer.twitter.com',
#        'display_url': 'developer.twitter.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6111518,
#    'friends_count': 12,
#    'listed_count': 12860,
#    'created_at': 'Wed May 23 06:01:13 +0000 2007',
#    'favourites_count': 31,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3672,
#    'lang': None,
#    'status': {'created_at': 'Wed Sep 18 16:41:39 +0000 2019',
#     'id': 1174362863118372867,
#     'id_str': '1174362863118372867',
#     'text': 'RT @TwitterDev: Today in Twitter Developer Labs we’re releasing a new way to filter Tweets in real-time. This is one of the most popular fe…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'TwitterDev',
#        'name': 'Twitter Dev',
#        'id': 2244994945,
#        'id_str': '2244994945',
#        'indices': [3, 14]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Wed Sep 18 16:36:10 +0000 2019',
#      'id': 1174361480734466048,
#      'id_str': '1174361480734466048',
#      'text': 'Today in Twitter Developer Labs we’re releasing a new way to filter Tweets in real-time. This is one of the most po… https://t.co/RElmBW5XxM',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/RElmBW5XxM',
#         'expanded_url': 'https://twitter.com/i/web/status/1174361480734466048',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 96,
#      'favorite_count': 190,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 96,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/6253282/1497491515',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'}],
#  'next_cursor': 0,
#  'next_cursor_str': '0',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
)

# %%
# !/usr/bin/env python tweepy-bots/bots/followfollowers.py

# import tweepy
import logging
from config import create_api
import time
# Out:
# python: can't open file 'tweepy-bots/bots/followfollowers.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-93-83d5c0549948> in <module>
#       3 # import tweepy
#       4 import logging
# ----> 5 from config import create_api
#       6 import time
#
# ModuleNotFoundError: No module named 'config'

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

def follow_followers(api):
    logger.info("Retrieving and following followers")
    for follower in tweepy.Cursor(api.followers).items():
        if not follower.following:
            logger.info(f"Following {follower.name}")
            follower.follow()

def main():
    api = create_api()
    while True:
        follow_followers(api)
        logger.info("Waiting...")
        time.sleep(60)

if __name__ == "__main__":
    main()

# %%
import base64
import requests

# %%
# personal client_key
client_key = '5SDCerBHlWzSBAzvBXonhZ6Xe'
client_secret = '8zeJxu7srcQN6uhQAvcsWXHM8q8pVdzys6g6kfyeQhyVLcdcIR'


key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

print(auth_resp.status_code)
auth_resp.json().keys()

access_token = auth_resp.json()['access_token']

search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)
}

search_params = {
    'q': 'General Election',
    'result_type': 'recent',
    'count': 2
}

search_url = '{}1.1/search/tweets.json'.format(base_url)

search_resp = requests.get(search_url, headers=search_headers, params=search_params)

tweet = search_resp.json()
# Out:
# 200

# %%
tweet
# Out:
# {'statuses': [{'created_at': 'Tue Oct 15 22:02:56 +0000 2019',
#    'id': 1184228186932072448,
#    'id_str': '1184228186932072448',
#    'text': 'RT @NTSUPresident: Is there going to be a General Election? Who knows!\n\nTo make things easier, we are going to be across all campuses over…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NTSUPresident',
#       'name': 'Bradley Fox',
#       'id': 352962111,
#       'id_str': '352962111',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 87163812,
#     'id_str': '87163812',
#     'name': 'W-0.963° N53.063°',
#     'screen_name': 'NTUGeography',
#     'location': 'NTU Brackenhurst Campus',
#     'description': 'Share our passion for geography and find out where it can take you. All our courses are accredited by the Royal Geographical Society (with IBG).',
#     'url': 'http://t.co/0WKYmPC7xE',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/0WKYmPC7xE',
#         'expanded_url': 'http://www.ntu.ac.uk/geography',
#         'display_url': 'ntu.ac.uk/geography',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 312,
#     'friends_count': 31,
#     'listed_count': 26,
#     'created_at': 'Tue Nov 03 10:42:28 +0000 2009',
#     'favourites_count': 51,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7647,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1620349642/Vignette_Main_hall_small_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1620349642/Vignette_Main_hall_small_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/87163812/1488548343',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Oct 14 14:36:55 +0000 2019',
#     'id': 1183753555297079296,
#     'id_str': '1183753555297079296',
#     'text': 'Is there going to be a General Election? Who knows!\n\nTo make things easier, we are going to be across all campuses… https://t.co/JKqmWlcLAb',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/JKqmWlcLAb',
#        'expanded_url': 'https://twitter.com/i/web/status/1183753555297079296',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 352962111,
#      'id_str': '352962111',
#      'name': 'Bradley Fox',
#      'screen_name': 'NTSUPresident',
#      'location': 'Nottingham',
#      'description': "Hi, I'm your Students' Union President at @TrentStudents. Expect updates and retweets about anything and everything Trent related!  He/Him",
#      'url': 'https://t.co/1URdkdlPMM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/1URdkdlPMM',
#          'expanded_url': 'http://trentstudents.org',
#          'display_url': 'trentstudents.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1918,
#      'friends_count': 504,
#      'listed_count': 19,
#      'created_at': 'Thu Aug 11 10:13:39 +0000 2011',
#      'favourites_count': 2048,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 2889,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '82D9F4',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1145594007092957184/6k5-kVOS_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1145594007092957184/6k5-kVOS_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/352962111/1561965850',
#      'profile_link_color': 'ED2FD7',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10,
#     'favorite_count': 12,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Oct 15 22:02:54 +0000 2019',
#    'id': 1184228179637985281,
#    'id_str': '1184228179637985281',
#    'text': '@shoe0nhead @JonClem310 @Bakari_Sellers yeah this is totally sane and normal to call active duty military officers… https://t.co/eYgHJzsjkH',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'shoe0nhead',
#       'name': 'shoe',
#       'id': 1733467884,
#       'id_str': '1733467884',
#       'indices': [0, 11]},
#      {'screen_name': 'JonClem310',
#       'name': 'ClemMedia 🧢',
#       'id': 979467036,
#       'id_str': '979467036',
#       'indices': [12, 23]},
#      {'screen_name': 'Bakari_Sellers',
#       'name': 'Bakari Sellers',
#       'id': 241201438,
#       'id_str': '241201438',
#       'indices': [24, 39]}],
#     'urls': [{'url': 'https://t.co/eYgHJzsjkH',
#       'expanded_url': 'https://twitter.com/i/web/status/1184228179637985281',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1184215159352504320,
#    'in_reply_to_status_id_str': '1184215159352504320',
#    'in_reply_to_user_id': 1733467884,
#    'in_reply_to_user_id_str': '1733467884',
#    'in_reply_to_screen_name': 'shoe0nhead',
#    'user': {'id': 1005165107402297344,
#     'id_str': '1005165107402297344',
#     'name': 'KGB OFFICER',
#     'screen_name': 'django_stiglitz',
#     'location': 'Moscow',
#     'description': 'омите́т Госуда́рственной Безопа́сности (КГБ), \nKomitet Gosudarstvennoy Bezopasnosti\nБоже, благослови Берни\nSowing Dischord for Soviet Union',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 222,
#     'friends_count': 320,
#     'listed_count': 7,
#     'created_at': 'Fri Jun 08 19:10:11 +0000 2018',
#     'favourites_count': 2199,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 15741,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1121900675695202304/nbc4UUQw_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1121900675695202304/nbc4UUQw_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1005165107402297344/1552005829',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.016,
#   'max_id': 1184228186932072448,
#   'max_id_str': '1184228186932072448',
#   'next_results': '?max_id=1184228179637985280&q=General%20Election&count=2&include_entities=1&result_type=recent',
#   'query': 'General+Election',
#   'refresh_url': '?since_id=1184228186932072448&q=General%20Election&result_type=recent&include_entities=1',
#   'count': 2,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Let's get Ultimatist list_id

# %%
GET https://api.twitter.com/1.1/lists/list.json?screen_name=paulynnyu

# %%
search_url = '{}1.1/lists/list.json'.format(base_url)

search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)
}

search_params = {
    'screen_name': 'paulynnyu',
    'skip_status': 'True'}
    
    
id_resp = requests.get(search_url,headers=search_headers,params=search_params)

list_id =  id_resp.json()

# %%
list_id
# Out:
# []

# %% [markdown]
# Let's test getting subscribers

# %%
search_url = '{}1.1/lists/subscribers.json'.format(base_url)

search_params = {
    'list_id': '1184228179637985281'} 

subs_resp = requests.get(search_url, headers=search_headers, params = search_params)



subscribers =  subs_resp.json()

# %%
subs_resp
# Out:
# <Response [404]>

# %%
auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

print(auth_resp.status_code)
auth_resp.json().keys()

access_token = auth_resp.json()['access_token']

search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)
}

search_params = {
    'q': 'General Election',
    'result_type': 'recent',
    'count': 2
}

search_url = '{}1.1/search/tweets.json'.format(base_url)

search_resp = requests.get(search_url, headers=search_headers, params=search_params)

tweet = search_resp.json()
